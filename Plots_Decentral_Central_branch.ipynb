# %%
from __future__ import division
import csv
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import pylab as pl
import matplotlib.ticker
get_ipython().magic(u'matplotlib inline')

# %%
total_energy_decentralized_y = pd.read_csv('total_energy_decentralized_y_npr.csv')
total_energy_decentralized_m3 = pd.read_csv('total_energy_decentralized_m3_npr.csv')
total_GHG_decentralized_y = pd.read_csv('total_GHG_decentralized_y_npr.csv')
total_GHG_decentralized_m3 = pd.read_csv('total_GHG_decentralized_m3_npr.csv')

process_energy_decentralized_y = pd.read_csv('process_energy_decentralized_y_npr.csv')
process_energy_decentralized_m3 = pd.read_csv('process_energy_decentralized_m3_npr.csv')
process_GHG_decentralized_y = pd.read_csv('process_GHG_decentralized_y_npr.csv')
process_GHG_decentralized_m3 = pd.read_csv('process_GHG_decentralized_m3_npr.csv')

# %%
total_energy_1=total_energy_decentralized_y[(total_energy_decentralized_y['grid_ID']==426)]
total_energy_m3=total_energy_decentralized_m3[(total_energy_decentralized_m3['grid_ID']==426)]
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1,2, 1)
plt.title('Total Energy',fontsize=14)
plt.plot(total_energy_1['People'],total_energy_1['Total_conveyance_capital_energy_y'],'r',label = 'conveyance capital energy')
plt.plot(total_energy_1['People'],total_energy_1['Total_conveyance_operational_energy_y'],'--r',label = 'conveyance operational energy')
plt.plot(total_energy_1['People'],total_energy_1['Total_Treatment_Capital_energy_y'],'b',label = 'treatment capital energy')
plt.plot(total_energy_1['People'],total_energy_1['Total_Treatment_Operational_energy_y'],'--b',label = 'treatment operational energy')
#plt.plot(total_energy_1['People'],total_energy_1['Total_Treatment_energy_offsets_y'],'--b',label = 'treatment offsets energy')
plt.plot(total_energy_1['People'],total_energy_1['Total_Energy_final_y'],'-ro',label = 'total energy')
legend = plt.legend(frameon = 1, fontsize=11,loc='best')
frame = legend.get_frame()
frame.set_edgecolor('black')
frame.set_facecolor('white')
plt.ylabel('Energy (MJ/y)',fontsize=12)
plt.xlabel('Number of People',fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')

ax = fig.add_subplot(1, 2, 2)
plt.title('Unit Energy',fontsize=14)
plt.plot(total_energy_m3['People'],total_energy_m3['Total_conveyance_capital_energy_y_m3'],'r',label = 'conveyance capital energy')
plt.plot(total_energy_m3['People'],total_energy_m3['Total_conveyance_operational_energy_y_m3'],'--r',label = 'conveyance operational energy')
plt.plot(total_energy_m3['People'],total_energy_m3['Total_Treatment_Capital_energy_y_m3'],'b',label = 'treatment capital energy')
plt.plot(total_energy_m3['People'],total_energy_m3['Total_Treatment_Operational_energy_y_m3'],'--b',label = 'treatment operational energy')
#plt.plot(total_energy_1['People'],total_energy_1['Total_Treatment_energy_offsets_m3'],'--b',label = 'treatment offsets energy')
plt.plot(total_energy_m3['People'],total_energy_m3['Total_Energy_final_y_m3'],'-ro',label = 'total energy')
legend = plt.legend(frameon = 1, fontsize=11,loc='best')
frame = legend.get_frame()
frame.set_edgecolor('black')
frame.set_facecolor('white')
plt.ylabel('Unit Energy (MJ/m3)',fontsize=12)
plt.xlabel('Number of People',fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')

plt.show()

# %%
total_GHG_plot=total_GHG_decentralized_y[(total_GHG_decentralized_y['grid_ID']==149)]
total_GHG_plot_m3=total_GHG_decentralized_m3[(total_GHG_decentralized_m3['grid_ID']==149)]
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1,2, 1)
plt.title('Total GHG',fontsize=14)
plt.plot(total_GHG_plot['People'],total_GHG_plot['Total_conveyance_capital_GHG_y'],'r',label = 'conveyance capital GHG')
plt.plot(total_GHG_plot['People'],total_GHG_plot['Total_conveyance_operational_GHG_y'],'--r',label = 'conveyance operational GHG')
plt.plot(total_GHG_plot['People'],total_GHG_plot['Total_Treatment_Capital_GHG_y'],'b',label = 'treatment capital GHG')
plt.plot(total_GHG_plot['People'],total_GHG_plot['Total_Treatment_Operational_GHG_y'],'--b',label = 'treatment operational GHG')
plt.plot(total_GHG_plot['People'],total_GHG_plot['Total_GHG_final_y'],'-ro',label = 'total GHG')
legend = plt.legend(frameon = 1, fontsize=11,loc='best')
frame.set_edgecolor('black')
frame.set_facecolor('white')
plt.ylabel('GHG (kgCO2/y)',fontsize=12)
plt.xlabel('Number of People served',fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')

ax = fig.add_subplot(1, 2, 2)
plt.title('Unit GHG',fontsize=14)
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_conveyance_capital_GHG_y_m3'],'r',label = 'conveyance capital GHG')
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_conveyance_operational_GHG_y_m3'],'--r',label = 'conveyance operational GHG')
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_Treatment_Capital_GHG_y_m3'],'b',label = 'treatment capital GHG')
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_Treatment_Operational_GHG_y_m3'],'--b',label = 'treatment operational GHG')
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_GHG_final_y_m3'],'-ro',label = 'total GHG')
legend = plt.legend(frameon = 1, fontsize=11,loc='best')
frame.set_edgecolor('black')
frame.set_facecolor('white')
plt.ylabel('Unit GHG (kgCO$_2$/m$^3$)',fontsize=12)
plt.xlabel('Number of People served',fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=2, fancybox=True, shadow=True,fontsize=14)

plt.show()

# %%
process_energy_dec_m3_plot_low=process_energy_decentralized_m3[(process_energy_decentralized_m3['grid_ID']==375)]
process_energy_dec_m3_plot_high=process_energy_decentralized_m3[(process_energy_decentralized_m3['grid_ID']==375)]

energy_plot_dec_first_low=process_energy_dec_m3_plot_low[1:2]
energy_plot_dec_last_low=process_energy_dec_m3_plot_low[(-1-1):-1]
energy_plot_dec_first_high=process_energy_dec_m3_plot_high[1:2]
energy_plot_dec_last_high=process_energy_dec_m3_plot_high[(-1-1):-1]

frames=[energy_plot_dec_first_low, energy_plot_dec_last_low]
energy_plot_dec=pd.concat(frames)
energy_plot_dec=energy_plot_dec[['Pipe_capital_energy_final_y_m3','Pump_capital_energy_final_y_m3','Tank_capital_energy_final_y_m3', 'Pipe_operat_energy_final_y_m3', 'Pump_operat_energy_final_y_m3','MBR_Operational_energy_final_y_m3','MBR_Capital_energy_final_y_m3','Sludge_transport_energy_final_y_m3','Chlorine_operational_energy_final_y_m3','Sludge_thick_dewater_energy_final_y_m3','Grinder_Capital_energy_final_y_m3','Grinder_Operational_energy_final_y_m3','UV_Capital_energy_final_y_m3','UV_Operational_energy_final_y_m3','SF_Capital_energy_final_y_m3','SF_Operational_energy_final_y_m3']]
energy_plot_dec2=energy_plot_dec

process_GHG_dec_m3_plot_low=process_GHG_decentralized_m3[(process_GHG_decentralized_m3['grid_ID']==375)]
process_GHG_dec_m3_plot_high=process_GHG_decentralized_m3[(process_GHG_decentralized_m3['grid_ID']==375)]

GHG_plot_dec_first_low=process_GHG_dec_m3_plot_low[1:2]
GHG_plot_dec_last_low=process_GHG_dec_m3_plot_low[(-1-1):-1]
GHG_plot_dec_first_high=process_GHG_dec_m3_plot_high[1:2]
GHG_plot_dec_last_high=process_GHG_dec_m3_plot_high[(-1-1):-1]

frames=[GHG_plot_dec_first_low,GHG_plot_dec_last_low]
GHG_plot_dec=pd.concat(frames)
GHG_plot_dec=GHG_plot_dec[['Pipe_capital_GHG_final_y_m3','Pump_capital_GHG_final_y_m3','Tank_capital_GHG_final_y_m3', 'Pipe_operat_GHG_final_y_m3', 'Pump_operat_GHG_final_y_m3','MBR_Operational_GHG_final_y_m3','MBR_Capital_GHG_final_y_m3','Sludge_transport_GHG_final_y_m3','Chlorine_operational_GHG_final_y_m3','MBR_direct_GHG_final_y_m3','Sludge_thick_dewater_GHG_final_y_m3','Sludge_disposal_GHG_final_y_m3','Grinder_Operational_GHG_final_y_m3','UV_Capital_GHG_final_y_m3','UV_Operational_GHG_final_y_m3','SF_Capital_GHG_final_y_m3','SF_Operational_GHG_final_y_m3','Sludge_direct_central_y_m3']]
GHG_plot_dec2=GHG_plot_dec

energy_plot_dec2['MBR_GHG_dierct']=0
energy_plot_dec2.columns=['Pipe embodied energy','Pump embodied energy','Tank embodied energy', 'Pipe maintenance energy', 'Pump operational energy','MBR operational energy','MBR embodied energy','Sludge transportation energy','Chlorine manufacturing energy','MBR_GHG_dierct','Sludge thickening&dewatering energy','Grinder pump embodied energy','Grinder pump operational energy','UV embodied energy','UV operational energy','Screen Filter embodied energy','Screen Filter operational energy']
energy_plot_dec2['Other']=energy_plot_dec2['Tank embodied energy']+energy_plot_dec2['Pipe maintenance energy']+energy_plot_dec2['Sludge transportation energy']+energy_plot_dec2['Sludge thickening&dewatering energy']+energy_plot_dec2['Grinder pump embodied energy']+energy_plot_dec2['Screen Filter embodied energy']+energy_plot_dec2['Screen Filter operational energy']+energy_plot_dec2['Pump embodied energy']+energy_plot_dec2['Grinder pump operational energy']+energy_plot_dec2['UV embodied energy']
energy_plot_dec3=energy_plot_dec2
energy_plot_dec3 = energy_plot_dec3.drop(['Tank embodied energy','Pipe maintenance energy','Sludge transportation energy','Sludge thickening&dewatering energy','Grinder pump embodied energy','Screen Filter embodied energy','Screen Filter operational energy','Pump embodied energy','Grinder pump operational energy','UV embodied energy','MBR_GHG_dierct'],1)
energy_plot_dec3=energy_plot_dec3/3.6

GHG_plot_dec2.columns=['Pipe embodied','Pump embodied GHG','Tank embodied GHG', 'Pipe maintainance GHG', 'Pump operation','MBR operation','MBR construction','Sludge transport GHG','Chlorine manufacturing','MBR Direct GHG','Sludge thickening&dewatering GHG','Sludge disposal GHG','Grinder operational GHG','UV embodied GHG','UV operation','Screen Filter embodied GHG','Screen Filter operational GHG','Sludge disposal direct GHG']
GHG_plot_dec2['Other']=GHG_plot_dec2['Tank embodied GHG']+GHG_plot_dec2['Pipe maintainance GHG']+GHG_plot_dec2['Sludge transport GHG']+GHG_plot_dec2['Sludge thickening&dewatering GHG']+GHG_plot_dec2['Screen Filter embodied GHG']+GHG_plot_dec2['Screen Filter operational GHG']+GHG_plot_dec2['UV embodied GHG']+GHG_plot_dec2['Pump embodied GHG']+GHG_plot_dec2['Grinder operational GHG']+GHG_plot_dec2['Sludge disposal GHG']+GHG_plot_dec2['Sludge disposal direct GHG']
GHG_plot_dec3=GHG_plot_dec2
GHG_plot_dec3 = GHG_plot_dec3.drop(['Tank embodied GHG','Pipe maintainance GHG','Sludge transport GHG','Sludge thickening&dewatering GHG','Screen Filter embodied GHG','Screen Filter operational GHG','UV embodied GHG','Pump embodied GHG','Grinder operational GHG','Sludge disposal GHG','Sludge disposal direct GHG','MBR Direct GHG'],1)

# %%
fig = plt.figure(figsize=(9, 6))

ax = fig.add_subplot(121) # Create matplotlib axes
ax2 = fig.add_subplot(122) # Create another axes that shares the same x-axis as ax.
width=0.5
energy_plot_dec3.index=['Low Demand','High Demand']
GHG_plot_dec3.index=['Low Demand','High Demand']

b=GHG_plot_dec3.plot(kind='bar',  stacked=True, colormap='PRGn', width =width ,ax=ax2,legend=False, secondary_y=True,fontsize=16)
a=energy_plot_dec3.plot(kind='bar', stacked=True,colormap='PRGn',width =width , ax=ax,  legend=False,fontsize=16)

a.set_ylabel('Unit Energy (kWh/m$^3$)',fontsize=18)
b.set_ylabel('Unit GHG emissions (kgCO$_2(eq)$/m$^3$)',fontsize=18)


a.set_ylim(0,3.5)
b.set_ylim(0,0.40)
fig.autofmt_xdate()

plt.yticks(fontsize=16)
plt.text(-1.7,0.41,"Decentralized Reuse", fontsize=18, weight="bold")

#a.legend(loc='lower center', bbox_to_anchor=(-0.1, 1.05), ncol=2, fancybox=True, shadow=True,fontsize=16)
#b.legend(loc='lower center', bbox_to_anchor=(-0.1, 1.05),ncol=2, fancybox=True, shadow=True,fontsize=16)
fig.tight_layout()
handles, labels = b.get_legend_handles_labels()
a.legend(reversed(handles), reversed(labels), loc='lower center', bbox_to_anchor=(1.15, 1.07),ncol=2, fancybox=True, shadow=True,fontsize=16)  # reverse to keep order consistent

# %%
energy_plot_dec3
# Out:
#              Pipe embodied energy  Pump operational energy  \
# Low Demand               0.099039                 0.346249
# High Demand              0.014605                 0.302055
#
#              MBR operational energy  MBR embodied energy  \
# Low Demand                 1.694457                  0.2
# High Demand                0.737555                  0.2
#
#              Chlorine manufacturing energy  UV operational energy     Other
# Low Demand                        0.176762               0.006038  0.189829
# High Demand                       0.176734               0.000377  0.177573

# %%
total_energy_centralized_m3 = pd.read_csv('C:\Users\Olga\Documents\RENUWIT\Decentralization_SF\Decentralization_model\\total_energy_centralized_m3_branch_npr.csv')
total_GHG_centralized_m3 = pd.read_csv('C:\Users\Olga\Documents\RENUWIT\Decentralization_SF\Decentralization_model\\total_GHG_centralized_m3_branch_npr.csv')

process_energy_centralized_m3 = pd.read_csv('C:\Users\Olga\Documents\RENUWIT\Decentralization_SF\Decentralization_model\\process_energy_centralized_m3_branch_npr.csv')
process_GHG_centralized_m3 = pd.read_csv('C:\Users\Olga\Documents\RENUWIT\Decentralization_SF\Decentralization_model\\process_GHG_centralized_m3_branch_npr.csv')

# %%
fig = plt.figure(figsize=(14, 5))
ax = fig.add_subplot(1, 2, 1)

total_GHG_plot_m3=total_GHG_decentralized_m3[(total_GHG_decentralized_m3['grid_ID']==149)]

plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_conveyance_capital_GHG_y_m3'],':r',label = 'conveyance capital GHG',linewidth=3)
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_conveyance_operational_GHG_y_m3'],'--r',label = 'conveyance operational GHG',linewidth=2)
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_Treatment_Capital_GHG_y_m3'],'b',label = 'treatment capital GHG',linewidth=2)
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_Treatment_Operational_GHG_y_m3'],'-.b',label = 'treatment operational GHG', linewidth=3)
plt.plot(total_GHG_plot_m3['People'],total_GHG_plot_m3['Total_GHG_final_y_m3'],'-ro',label = 'total GHG',linewidth=2)
plt.title('Decentralized Reuse',fontsize=22,fontweight='bold')
frame.set_edgecolor('black')
frame.set_facecolor('white')
plt.ylabel('Unit GHG (kgCO$_2$/m$^3$)',fontsize=20)
plt.xlabel('Number of People served',fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
plt.xlim(0,10000)
plt.ylim(0, 0.5)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))


total_energy_central_plot=total_GHG_centralized_m3[(total_energy_centralized_m3['grid_ID']==149)]

ax = fig.add_subplot(1, 2, 2)

plt.plot(total_energy_central_plot['People'],total_energy_central_plot['Total_conveyance_capital_GHG_central_y'],':r',label = 'conveyance capital GHG', linewidth=3.5)
plt.plot(total_energy_central_plot['People'],total_energy_central_plot['Total_conveyance_operational_GHG_central_y'],'--r',label = 'conveyance operational GHG',linewidth=2)
plt.plot(total_energy_central_plot['People'],total_energy_central_plot['Total_conveyance_operational_GHG_collection_y'],'-m',label = 'conveyance collection operational GHG',linewidth=2)
plt.plot(total_energy_central_plot['People'],total_energy_central_plot['Total_Treatment_capital_GHG_y'],'b',label = 'treatment capital GHG',linewidth=2)
plt.plot(total_energy_central_plot['People'],total_energy_central_plot['Total_Treatment_operational_GHG_y'],'-.b',label = 'treatment operational GHG', linewidth=3.5)
plt.plot(total_energy_central_plot['People'],total_energy_central_plot['Total_GHG_m3'],'-ro',label = 'total GHG')
plt.title('Centralized Reuse',fontsize=22,fontweight='bold')
frame.set_edgecolor('black')
frame.set_facecolor('white')
plt.ylim(0, 0.5)
plt.ylabel('Unit GHG (kgCO$_2$/m$^3$)',fontsize=20)
plt.xlabel('Number of People served',fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.xlim(0,10000)
plt.legend(loc='lower center', bbox_to_anchor=(-0.2, 1.1),
          ncol=2, fancybox=True, shadow=True,fontsize=20)
fig.tight_layout()
plt.show()

# %%
grid_ID_to_show=546

total_energy_decentralized_m3['m3_day']=total_energy_decentralized_m3['People']*0.2
total_energy_centralized_m3['m3_day']=total_energy_centralized_m3['People']*0.2
total_GHG_decentralized_m3['m3_day']=total_GHG_decentralized_m3['People']*0.2
total_GHG_centralized_m3['m3_day']=total_GHG_centralized_m3['People']*0.2

total_energy_decentralized_1=total_energy_decentralized_m3[(total_energy_decentralized_m3['grid_ID']==grid_ID_to_show)]
total_energy_central_1=total_energy_centralized_m3[(total_energy_centralized_m3['grid_ID']==grid_ID_to_show)]
total_GHG_decentralized_1=total_GHG_decentralized_m3[(total_GHG_decentralized_m3['grid_ID']==grid_ID_to_show)]
total_GHG_central_1=total_GHG_centralized_m3[(total_GHG_centralized_m3['grid_ID']==grid_ID_to_show)]

fig = plt.figure(figsize=(12, 5))
fig.subplots_adjust(wspace=0.27)
ax = fig.add_subplot(1,2,1)
plt.title('Unit Energy',fontsize=14)
plt.plot(
    total_energy_decentralized_1['m3_day'],
    total_energy_decentralized_1['Total_Energy_final_y_m3']/3.6,
    '-r',
    linewidth=2.0,
    label = 'decentralized')
plt.plot(total_energy_central_1['m3_day'],total_energy_central_1['Total_Energy_m3']/3.6,'--b',linewidth=2.0,label = 'centralized')
legend = plt.legend(frameon = 1, fontsize=14,loc='best')
plt.ylabel('Unit Energy (kWh/m$^3$)',fontsize=14)
plt.xlabel('NPR demand (m$^3$/day)',fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0,2000)

ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
x = total_energy_decentralized_1['m3_day']
y = total_energy_decentralized_1['Total_Energy_final_y_m3']/3.6
error = np.random.uniform(0.2, 0.2, size=y.shape)
y += np.random.uniform(0, 0, size=y.shape)
plt.plot(x, y, 'k-')
plt.fill_between(x, y-error, y+error,facecolor='red',alpha=0.08)
x2 = total_energy_central_1['m3_day']
y2 = total_energy_central_1['Total_Energy_m3']/3.6
error2 = np.random.uniform(0.15, 0.15, size=y.shape)
y2 += np.random.uniform(0, 0, size=y.shape)
plt.plot(x2, y2, 'k--')
plt.fill_between(x2, y2-error2, y2+error2,facecolor='blue',alpha=0.1)


ax = fig.add_subplot(1,2,2)
plt.title('Unit GHG emissions',fontsize=14)
plt.plot(total_GHG_decentralized_1['m3_day'],total_GHG_decentralized_1['Total_GHG_final_y_m3'],'-r',linewidth=2.0,label = 'decentralized')
plt.plot(total_GHG_central_1['m3_day'],total_GHG_central_1['Total_GHG_m3'],'--b',linewidth=2.0,label = 'centralized')
legend = plt.legend(frameon = 1, fontsize=14,loc='best')
plt.ylabel('Unit GHG emissions (kgCO$_2(eq)$/m$^3$)',fontsize=14)
plt.xlabel('NPR demand (m$^3$/day)',fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0,2000)

ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
x = total_GHG_decentralized_1['m3_day']
y = total_GHG_decentralized_1['Total_GHG_final_y_m3']
error = np.random.uniform(0.02, 0.02, size=y.shape)
y += np.random.uniform(0, 0, size=y.shape)
plt.plot(x, y, 'k-')
plt.fill_between(x, y-error, y+error,facecolor='red',alpha=0.08)
x2 = total_GHG_central_1['m3_day']
y2 = total_GHG_central_1['Total_GHG_m3']
error2 = np.random.uniform(0.015, 0.015, size=y.shape)
y2 += np.random.uniform(0, 0, size=y.shape)
plt.plot(x2, y2, 'k--')
plt.fill_between(x2, y2-error2, y2+error2,facecolor='blue',alpha=0.1)

plt.show()

# %%
grid_ID_to_show=280

total_energy_decentralized_1=total_energy_decentralized_m3[(total_energy_decentralized_m3['grid_ID']==grid_ID_to_show)]
total_energy_central_1=total_energy_centralized_m3[(total_energy_centralized_m3['grid_ID']==grid_ID_to_show)]
total_GHG_decentralized_1=total_GHG_decentralized_m3[(total_GHG_decentralized_m3['grid_ID']==grid_ID_to_show)]
total_GHG_central_1=total_GHG_centralized_m3[(total_GHG_centralized_m3['grid_ID']==grid_ID_to_show)]

fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(1,1,1)
plt.plot(
    total_energy_decentralized_1['m3_day'],
    total_energy_decentralized_1['Total_Energy_final_y_m3']/3.6,
    '-r',
    linewidth=2.0,
    label = 'decentralized')
plt.plot(total_energy_central_1['m3_day'],total_energy_central_1['Total_Energy_m3']/3.6,'--b',linewidth=2.0,label = 'centralized')
legend = plt.legend(frameon = 1, fontsize=29,loc='best')
plt.ylabel('Unit Energy (kWh/m$^3$)',fontsize=29)
plt.xlabel('NPR demand (m$^3$/day)',fontsize=29)
plt.xticks(fontsize=27)
plt.yticks(fontsize=27)
plt.xlim(0,2000)


ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
x = total_energy_decentralized_1['m3_day']
y = total_energy_decentralized_1['Total_Energy_final_y_m3']/3.6
error = np.random.uniform(0.2, 0.2, size=y.shape)
y += np.random.uniform(0, 0, size=y.shape)
plt.plot(x, y, 'k-')
plt.fill_between(x, y-error, y+error,facecolor='red',alpha=0.08)
x2 = total_energy_central_1['m3_day']
y2 = total_energy_central_1['Total_Energy_m3']/3.6
error2 = np.random.uniform(0.15, 0.15, size=y.shape)
y2 += np.random.uniform(0, 0, size=y.shape)
plt.plot(x2, y2, 'k--')
plt.fill_between(x2, y2-error2, y2+error2,facecolor='blue',alpha=0.1)

plt.show()

# %%
grid_ID_to_show=280

fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(1,1,1)
plt.plot(total_GHG_decentralized_1['m3_day'],total_GHG_decentralized_1['Total_GHG_final_y_m3'],'-r',linewidth=2.0,label = 'decentralized')
plt.plot(total_GHG_central_1['m3_day'],total_GHG_central_1['Total_GHG_m3'],'--b',linewidth=2.0,label = 'centralized')
legend = plt.legend(frameon = 1, fontsize=29,loc='best')
plt.ylabel('Unit GHG emissions \n(kgCO$_2(eq)$/m$^3$)',fontsize=29)
plt.xlabel('NPR demand (m$^3$/day)',fontsize=29)
plt.xticks(fontsize=27)
plt.yticks(fontsize=27)
plt.xlim(0,2000)
plt.ylim(0.13,0.40)

ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.yaxis.grid(color='gray', linestyle=':')
ax.xaxis.grid(color='gray', linestyle=':')
x = total_GHG_decentralized_1['m3_day']
y = total_GHG_decentralized_1['Total_GHG_final_y_m3']
error = np.random.uniform(0.02, 0.02, size=y.shape)
y += np.random.uniform(0, 0, size=y.shape)
plt.plot(x, y, 'k-')
plt.fill_between(x, y-error, y+error,facecolor='red',alpha=0.08)
x2 = total_GHG_central_1['m3_day']
y2 = total_GHG_central_1['Total_GHG_m3']
error2 = np.random.uniform(0.015, 0.015, size=y.shape)
y2 += np.random.uniform(0, 0, size=y.shape)
plt.plot(x2, y2, 'k--')
plt.fill_between(x2, y2-error2, y2+error2,facecolor='blue',alpha=0.1)

plt.show()

# %%
process_energy_central_m3_plot=process_energy_centralized_m3[(process_energy_centralized_m3['grid_ID']==grid_ID_to_show)]
process_energy_central_m3_plot_low=process_energy_centralized_m3[(process_energy_centralized_m3['grid_ID']==149)]
process_energy_central_m3_plot_high=process_energy_centralized_m3[(process_energy_centralized_m3['grid_ID']==375)]
#energy_plot_central=process_energy_central_m3_plot[(-1-1):-1]

process_energy_central_m3=process_energy_centralized_m3[['Pipe_capital_energy_final_y','Pump_capital_energy_final_y','Tank_capital_energy_final_y', 'Pipe_operat_energy_final_y', 'Pump_operat_energy_final_y','Pipe_construction_energy_final_y','Pipe_excavation_energy_final_y','Pipe_transport_energy_final_y','tank_const_energy_final_y','tank_transport_energy_final_y','pump_construction_energy_final_y','pump_transport_energy_final_y','Treatment_operational_energy_y','Treatment_capital_energy_y','RSF_capital_energy_y','RSF_operational_energy_y','CoagFlocc_Capital_energy_y','CoagFlocc_Operational_energy_y','Chlorine_operational_energy_y','Sludge_transport_energy_final_y','Total_conveyance_operational_energy_collection_y']]


process_GHG_central_m3=process_GHG_centralized_m3[['grid_ID','Pipe_capital_GHG_final_y','Pump_capital_GHG_final_y','Tank_capital_GHG_final_y', 'Pipe_operat_GHG_final_y', 'Pump_operat_GHG_final_y','Pipe_construction_GHG_final_y','Pipe_excavation_GHG_final_y','Pipe_transport_GHG_final_y','tank_const_GHG_final_y','tank_transport_GHG_final_y','pump_construction_GHG_final_y','pump_transport_GHG_final_y','Treatment_operational_GHG_y','Treatment_capital_GHG_y','RSF_capital_GHG_y','RSF_operational_GHG_y','CoagFlocc_Capital_GHG_y','CoagFlocc_Operational_GHG_y','Chlorine_operational_GHG_y','Sludge_transport_GHG_y','Sludge_disposal_GHG_y','Treatment_operational_direct_GHG_y','Total_conveyance_operational_GHG_collection_y']]

process_GHG_central_m3_plot=process_GHG_centralized_m3[(process_GHG_centralized_m3['grid_ID']==grid_ID_to_show)]
process_GHG_central_m3_plot_low=process_GHG_centralized_m3[(process_GHG_centralized_m3['grid_ID']==149)]
process_GHG_central_m3_plot_high=process_GHG_centralized_m3[(process_GHG_centralized_m3['grid_ID']==375)]

# %%
#only plot 1st and last (low demand - high demand)
energy_plot_central_first_low=process_energy_central_m3_plot_low[1:2]
energy_plot_central_last_low=process_energy_central_m3_plot_low[(-1-1):-1]
energy_plot_central_first_high=process_energy_central_m3_plot_high[1:2]
energy_plot_central_last_high=process_energy_central_m3_plot_high[(-1-1):-1]

frames=[energy_plot_central_first_low,energy_plot_central_last_low,energy_plot_central_first_high,energy_plot_central_last_high]
energy_plot_central=pd.concat(frames)
energy_plot_central['MBR_direct']=0
energy_plot_central=energy_plot_central[['Pipe_capital_energy_final_y','Pipe_operat_energy_final_y', 'Pump_operat_energy_final_y','tank_const_energy_final_y','tank_transport_energy_final_y','pump_construction_energy_final_y','pump_transport_energy_final_y','Treatment_operational_energy_y','Treatment_capital_energy_y','Chlorine_operational_energy_y','RSF_capital_energy_y','RSF_operational_energy_y','CoagFlocc_Capital_energy_y','CoagFlocc_Operational_energy_y','Sludge_transport_energy_final_y','MBR_direct','Total_conveyance_operational_energy_collection_y']]
energy_plot_central2=energy_plot_central

GHG_plot_central_first_low=process_GHG_central_m3_plot_low[1:2]
GHG_plot_central_last_low=process_GHG_central_m3_plot_low[(-1-1):-1]
GHG_plot_central_first_high=process_GHG_central_m3_plot_high[1:2]
GHG_plot_central_last_high=process_GHG_central_m3_plot_high[(-1-1):-1]

frames=[GHG_plot_central_first_low,GHG_plot_central_last_low,GHG_plot_central_first_high,GHG_plot_central_last_high]
GHG_plot_central=pd.concat(frames)
GHG_plot_central=GHG_plot_central[['Pipe_capital_GHG_final_y','Pipe_operat_GHG_final_y', 'Pump_operat_GHG_final_y','tank_const_GHG_final_y','tank_transport_GHG_final_y','pump_construction_GHG_final_y','pump_transport_GHG_final_y','Treatment_operational_GHG_y','Treatment_capital_GHG_y','Chlorine_operational_GHG_y','RSF_capital_GHG_y','RSF_operational_GHG_y','CoagFlocc_Capital_GHG_y','CoagFlocc_Operational_GHG_y','Sludge_transport_GHG_y','Sludge_disposal_GHG_y','Treatment_operational_direct_GHG_y','Total_conveyance_operational_GHG_collection_y']]
GHG_plot_central2=GHG_plot_central

energy_plot_central2.columns=['Pipe embodied','Pipe maintainance','Pump operation','tank construction','tank materials transportation','pump construction','pump materials transportation','Secondary treatment operation','Secondary treatment construction','Chlorine manufacturing','Rapid sand filtration construction','Rapid sand filtration operation','Coagulation&Flocculation contruction','Coagulation&Flocculation operation','Sludge transportation','Direct GHG','Wastewater collection']
#energy_plot_central2['Pipe embodied']=energy_plot_central2['Pipe excavation']+energy_plot_central2['Pipe construction']
energy_plot_central2['Other']=energy_plot_central2['tank materials transportation']+energy_plot_central2['Pipe maintainance']+energy_plot_central2['pump construction']+energy_plot_central2['pump materials transportation']+energy_plot_central2['Rapid sand filtration construction']+energy_plot_central2['Rapid sand filtration operation']+energy_plot_central2['Sludge transportation']+energy_plot_central2['Coagulation&Flocculation contruction']+energy_plot_central2['tank construction']+energy_plot_central2['Coagulation&Flocculation operation']
energy_plot_central3=energy_plot_central2
energy_plot_central3 = energy_plot_central3.drop(['tank materials transportation','Pipe maintainance','pump construction','pump materials transportation','Rapid sand filtration construction','Sludge transportation','Coagulation&Flocculation contruction','tank construction','Rapid sand filtration operation','Coagulation&Flocculation operation','Direct GHG'],1)


GHG_plot_central2.columns=['Pipe embodied','Pipe maintainance','Pump operation','tank construction','tank materials transportation','pump construction','pump materials transportation','Secondary treatment operation','Secondary treatment construction','Chlorine manufacturing','Rapid sand filtration construction','Rapid sand filtration operation','Coagulation&Flocculation contruction','Coagulation&Flocculation operation','Sludge transportation','Sludge disposal','Direct GHG','Wastewater collection']
#GHG_plot_central2['Pipe embodied']=GHG_plot_central2['Pipe excavation']+GHG_plot_central2['Pipe construction']
GHG_plot_central2['Other']=GHG_plot_central2['tank materials transportation']+GHG_plot_central2['Pipe maintainance']+GHG_plot_central2['pump construction']+GHG_plot_central2['pump materials transportation']+GHG_plot_central2['Rapid sand filtration construction']+GHG_plot_central2['Sludge transportation']+GHG_plot_central2['Rapid sand filtration operation']+GHG_plot_central2['Coagulation&Flocculation contruction']+GHG_plot_central2['tank construction']+GHG_plot_central2['Sludge disposal']+GHG_plot_central2['Coagulation&Flocculation operation']+GHG_plot_central2['Direct GHG']
GHG_plot_central3=GHG_plot_central2
GHG_plot_central3 = GHG_plot_central3.drop(['tank materials transportation','Pipe maintainance','pump construction','pump materials transportation','Rapid sand filtration construction','Sludge transportation','Coagulation&Flocculation contruction','tank construction','Rapid sand filtration operation','Sludge disposal','Coagulation&Flocculation operation','Direct GHG'],1)

energy_plot_central3=energy_plot_central3/3.6

# %%
energy_plot_central3
# Out:
#        Pipe embodied  Pump operation  Secondary treatment operation  \
# 13777       0.000280        0.318540                       0.666667
# 13795       0.000054        0.215574                       0.666667
# 11845       0.060896        1.217233                       0.666667
# 11863       0.011794        0.913361                       0.666667
#
#        Secondary treatment construction  Chlorine manufacturing  \
# 13777                          0.138889                0.176725
# 13795                          0.138889                0.176725
# 11845                          0.138889                0.176725
# 11863                          0.138889                0.176725
#
#        Wastewater collection     Other
# 13777               0.000000  0.116975
# 13795               0.000000  0.113518
# 11845               0.077778  0.119312
# 11863               0.077778  0.114418

# %%
fig = plt.figure(figsize=(11,6))
ax = fig.add_subplot(121) # Create matplotlib axes
ax2 = fig.add_subplot(122) # Create another axes that shares the same x-axis as ax.
width=0.7
energy_plot_central3.index=['Low Demand','High Demand','Low Demand','High Demand']
GHG_plot_central3.index=['Low Demand','High Demand','Low Demand','High Demand']

a=energy_plot_central3.plot(kind='bar', stacked=True,width =width ,ax=ax,legend=False,colormap='PRGn',fontsize=16)
b=GHG_plot_central3.plot(kind='bar', stacked=True,width =width ,ax=ax2,legend=False,colormap='PRGn',secondary_y=True,fontsize=16)
#ax.set_xticklabels(energy_plot_central3.index, rotation=0)
fig.autofmt_xdate()

a.set_ylabel('Unit Energy (kWh/m$^3$)',fontsize=18)
b.set_ylabel('Unit GHG emissions (kgCO$_2(eq)$/m$^3$)',fontsize=18)

plt.text(-2.3,0.41,"Centralized Reuse", fontsize=18, weight="bold")
a.set_ylim(0,3.5)
b.set_ylim(0,0.40)

plt.yticks(fontsize=16)
#b.legend(loc='lower center', bbox_to_anchor=(-0.1, 1.05),          ncol=2, fancybox=True, shadow=True,fontsize=16)
fig.tight_layout()
handles, labels = b.get_legend_handles_labels()
a.legend(reversed(handles), reversed(labels), loc='lower center', bbox_to_anchor=(1.15, 1.07),ncol=2, fancybox=True, shadow=True,fontsize=16)  # reverse to keep order consistent
